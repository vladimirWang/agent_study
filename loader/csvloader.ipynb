# %%
from langchain_community.document_loaders import csv_loader

loader = csv_loader.CSVLoader(file_path="stu.csv")

data = loader.load()

print(data)
# Out:
# [Document(metadata={'source': 'stu.csv', 'row': 0}, page_content='name: mike\nage: 12'), Document(metadata={'source': 'stu.csv', 'row': 1}, page_content='name: peter\nage: 32')]
