# %%
# 用社区版本的 model 类
from langchain_community.chat_models.tongyi import ChatTongyi
from langchain_core.messages import HumanMessage
from rich import print as rprint

model = ChatTongyi(model="qwen-max")

# BaseChatModel.invoke 只接受：str / PromptValue / list[BaseMessage]
# response = model.invoke([HumanMessage(content="你好")])
response = model.stream("你好，你是谁")

# %%
rprint(type(response))

for chunk in response:
    print(chunk.content, end="", flush=True)

# 如果你只关心文本
rprint("content:")
rprint(getattr(response, "content", response))
# Out:
# <class 'generator'>
# 你好！我是Qwen，这是我的英文名，你也可以叫我通义千问。我是阿里云自主研发的超大规模语言模型，能够帮助人们写故事、写公文、写邮件、写剧本等等，还能表达观点，玩游戏等。如果你有任何问题或需要帮助，请随时告诉我，我会尽力提供支持。
# content:
# <generator object BaseChatModel.stream at 0x125226ae0>
