# %%
from langchain.chat_models import init_chat_model
from dotenv import load_dotenv
import os
from langchain.agents import create_agent
from langchain_core.messages import HumanMessage

load_dotenv()


model = init_chat_model(
    model="qwen3.5-plus",
    model_provider="openai",
    api_key=os.getenv("DASHSCOPE_API_KEY"),
    base_url=os.getenv("DASHSCOPE_BASE_URL"),
)

agent = create_agent(model=model)
print("success")
# Out:
# success

# %% [markdown]
# 准备多模态消息

# %%
message = HumanMessage(content=[
        {
            "type": "text",
            "text": "描述一下这张图片"
        },
        {
            "type": "image",
            "url": "https://b0.bdstatic.com/aea0134360236f59d77ecfbb8b14ccb5.jpg@h_1280"
        }
    ])

# %%
stream = agent.stream({
    "messages": [message],
}, stream_mode= "messages")

for chunk, metadata in stream:
    if chunk.content:
        print(chunk.content, end="", flush=True)
# Out:
# 这张图片捕捉了一个充满激情的足球比赛瞬间，以下是详细的描述：
#
# **1. 主体人物：**
# *   **人物身份：** 图片中的主角是著名的西班牙足球运动员弗朗西斯科·法布雷加斯（Cesc Fàbregas），这是他在效力于阿森纳（Arsenal）足球俱乐部时期的照片。
# *   **动作与神态：** 他正张开双臂在绿茵场上奔跑，身体前倾，呈现出一种极具动感的姿态。他的嘴巴大张，似乎正在大声呐喊或欢呼，面部表情充满了兴奋、狂喜和激情，显然是在庆祝进球或球队的胜利。
# *   **着装细节：**
#     *   他身穿阿森纳经典的红色主场长袖球衣，胸前印有白色的“Fly Emirates”（阿联酋航空）赞助商标志，左胸有阿森纳的队徽，右胸是耐克的标志。
#     *   下身穿着白色的短裤，上面同样印有队徽。
#     *   他穿着白色的长球袜，袜口有红色条纹，脚蹬红黑相间的足球鞋。
#     *   值得注意的是，他双手戴着黑色的手套，这暗示了比赛当天的天气比较寒冷。
#
# **2. 背景环境：**
# *   **场地：** 脚下是修剪整齐的绿色草坪。
# *   **背景：** 背景被虚化处理（浅景深），突出了前景的人物。可以看到后面是坐满观众的看台，人群密密麻麻但看不清具体面孔。
# *   **广告牌：** 在人物头顶上方，可以看到模糊的广告牌，其中一部分绿色的字样显示为“power.com”。
#
# **总结：**
# 这是一张极具感染力的体育摄影作品，完美定格了球员在赛场上释放激情、享受胜利喜悦的高光时刻。

# %%
from ipywidgets import FileUpload
from IPython.display import display

uploader = FileUpload(accept="*", multiple=False)
display(uploader)
# Out:
# FileUpload(value=(), accept='*', description='Upload')

# %% [markdown]
# ## 拿到插件上传的图片病转成base64

# %%
import base64
print(uploader.value)

uploaded_file = uploader.value[0]
content_mv = uploaded_file['content']

img_bytes = bytes(content_mv)
img_b64 = base64.b64encode(img_bytes).decode('utf-8')
print(img_b64)
# Out:
# ()
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[10], line 4
#       1 import base64
#       2 print(uploader.value)
#       3
# ----> 4 uploaded_file = uploader.value[0]
#       5 content_mv = uploaded_file['content']
#       6
#       7 img_bytes = bytes(content_mv)
#
# IndexError: tuple index out of range

# %% [markdown]
# ## 用base64发送多模态消息

# %%
message = HumanMessage(content=[
        {
            "type": "text",
            "text": "描述一下这张图片"
        },
        {
            "type": "image",
            "base64": img_b64,
            "mime_type": "image/jpeg"
        }
    ])
stream = agent.stream({
    "messages": [message],
}, stream_mode= "messages")
for chunk, metadata in stream:
    if chunk.content:
        print(chunk.content, end="", flush=True)
# Out:
# 这张图片捕捉了一个充满激情和动感的足球比赛瞬间，以下是详细的描述：
#
# **1. 主体人物与动作：**
# *   **人物：** 图片的中心是一位年轻的男性足球运动员（看起来像是前阿森纳球星塞斯克·法布雷加斯 Cesc Fàbregas）。
# *   **动作：** 他正张开双臂，呈“T”字形在绿茵场上奔跑庆祝。他的身体前倾，左腿在前，右腿在后蹬地，显得非常有冲劲。
# *   **表情：** 他的嘴巴大张，面部表情极度兴奋和激动，似乎正在大声呐喊，宣泄着进球或胜利的喜悦。
#
# **2. 服装与装备：**
# *   **球衣：** 他身穿经典的阿森纳（Arsenal）主场球衣。这是一件红色长袖球衣，袖子上有白色的条纹设计。胸前印有白色的“Fly Emirates”（阿联酋航空）赞助商标志，左胸口有阿森纳的队徽，右胸口有耐克的标志。
# *   **下装：** 他穿着白色的短裤（左腿上有队徽）和白色的长球袜，袜口处有红色的横条和耐克标志。
# *   **其他装备：** 他手上戴着黑色的手套，脚上穿着红黑相间的足球鞋。戴手套这一细节暗示比赛当天的天气比较寒冷。
#
# **3. 背景与环境：**
# *   **场地：** 脚下是修剪整齐的绿色草坪。
# *   **背景：** 背景被虚化处理，突出了前景的人物。可以看到后面是坐满观众的看台，人头攒动，营造出热烈的比赛氛围。
# *   **广告牌：** 在球员头部上方，有一个模糊的场边广告牌，依稀可以看到绿色的“power.com”字样。
#
# 总的来说，这是一张非常经典的体育摄影作品，完美定格了球员在赛场上释放激情、庆祝成功的瞬间。
