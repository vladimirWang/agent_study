# %%
from langchain_core.output_parsers import StrOutputParser
from langchain_community.chat_models.tongyi import ChatTongyi
from langchain_core.prompts import PromptTemplate

prompt_template = PromptTemplate.from_template("邻居姓{lastname}生孩子了，{gender}，帮我起一个名字，只需要一个答案")

model = ChatTongyi(model="qwen-max")

str_parser = StrOutputParser()
chain = prompt_template | model | str_parser

res = chain.invoke({"gender": "男孩", "lastname": "周"})

print(res, type(res))
# Out:
# 周子涵 <class 'langchain_core.messages.base.TextAccessor'>
